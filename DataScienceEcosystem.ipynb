# %% [markdown]
# # **Data Science Tools and Ecosystem**

# %% [markdown]
# ## **Author: Megan Patzoldt**

# %% [markdown]
# ## In this notebook, data science tools and ecosystem are summarized.

# %% [markdown]
# ####  Some commonly used Languages include
# #### 1. Python
# #### 2. R
# #### 3. SQL
# #### 4. Java
# #### 5. MatLab

# %% [markdown]
# ### **Objectives**
# - List common Languages used for DataSci
# - List common libraries used for DataSci
# - Learn basics for Jupyter notebooks, RStudio and Github
# - Learn the importance of documentation and adding commments in projects for easier collaboration and code review

# %% [markdown]
# ### Some of the commonly used libraries include
# #### 1. Pandas
# #### 2. Numpy
# #### 3. PyTorch
# #### 4. Keras
# #### 5. TensorFlow

# %% [markdown]
# ## Data Science Tools
# | Data Science Tools |
# |---------------------|
# | JupyterNotebook  |
# | R Studio  |
# | Google Colab  |

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python.

# %%
# This is a simple arithmetic expression to multiply and add integers
(3*4)+5
# Out:
# 17

# %%
# To convert min to hours divide by 60 as below
200/60
# Out:
# 3.3333333333333335
